# %%
# Loading Libraries
from imblearn.over_sampling import SMOTE
from sklearn.datasets import make_classification
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
import pandas as pd

# %%
# Loading Data
data = pd.read_csv('C:\\Users\\student\\Documents\\DSE 6311\\Module 5\\rf_data.csv')
data = data.drop('Unnamed: 0', axis=1)
data
# Out:
#      ab.rOBA  ab.BAbip    ab.ISO    ab.SO%    ab.BB%    ab.LD%    ab.FB%  \
# 0      0.362     0.303 -1.205319 -1.529954 -1.524944 -0.604766 -0.355890
# 1      0.341     0.290 -1.286953 -1.551780 -1.563000 -0.612870 -0.357397
# 2      0.355     0.302 -1.307935 -1.529954 -1.524944 -0.609419 -0.360720
# 3      0.348     0.293 -1.289917 -1.606542 -1.545805 -0.606517 -0.357638
# 4      0.343     0.297 -1.310978 -1.534276 -1.520852 -0.608840 -0.355890
# ..       ...       ...       ...       ...       ...       ...       ...
# 715    0.311     0.294 -1.348444 -1.319890 -1.598890 -0.610573 -0.362065
# 716    0.301     0.289 -1.374474 -1.219847 -1.580682 -0.621353 -0.362065
# 717    0.306     0.279 -1.354869 -1.333623 -1.585183 -0.623579 -0.358687
# 718    0.314     0.283 -1.335754 -1.361721 -1.571778 -0.614013 -0.361215
# 719    0.308     0.288 -1.387834 -1.361721 -1.608204 -0.624686 -0.363118
#
#      ab.GB/FB  ab.Pull%  ab.Cent%  ...     sp.IBB    sp.HBP     sp.BK  \
# ...

# %%
# Splitting Data
X = data.drop('Team.Success', axis=1) 
y = data['Team.Success']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.22, random_state=123)

# Prinitng Before SMOTE Data
print("Before SMOTE:", Counter(y_train))

# Running SMOTE
smote = SMOTE(random_state=123)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Printing After SMOTE Data
print("After SMOTE:", Counter(y_train_res))
# Out:
# Before SMOTE: Counter({1: 389, 2: 137, 4: 18, 3: 17})
# After SMOTE: Counter({2: 389, 1: 389, 4: 389, 3: 389})

# %%
# Creating New Resampled Data
X_resampled_data = pd.DataFrame(X_train_resampled, columns=X.columns)
y_resampled_data = pd.Series(y_train_resampled, name='TeamSuccess')

# Combining Resampled Data
balanced_data = pd.concat([X_resampled_data, y_resampled_data], axis=1)
balanced_data
# Out:
#        ab.rOBA  ab.BAbip    ab.ISO    ab.SO%    ab.BB%    ab.LD%    ab.FB%  \
# 0     0.346000  0.312000 -1.338907 -1.578723 -1.627284 -0.644956 -0.359356
# 1     0.320000  0.298000 -1.381124 -1.508664 -1.637063 -0.648524 -0.359025
# 2     0.326000  0.300000 -1.326371 -1.306360 -1.554344 -0.598869 -0.367175
# 3     0.343000  0.310000 -1.289917 -1.471602 -1.554344 -0.638716 -0.359025
# 4     0.339000  0.295000 -1.210702 -1.254133 -1.516785 -0.620794 -0.357638
# ...        ...       ...       ...       ...       ...       ...       ...
# 1551  0.342434  0.310187 -1.327963 -1.452365 -1.547279 -0.629545 -0.359294
# 1552  0.353762  0.324047 -1.261090 -1.363503 -1.542625 -0.620357 -0.360490
# 1553  0.350828  0.316948 -1.298804 -1.512323 -1.579068 -0.608511 -0.358279
# 1554  0.340474  0.296422 -1.271121 -1.514645 -1.556950 -0.632057 -0.360201
# 1555  0.336467  0.299893 -1.326371 -1.508320 -1.573821 -0.643963 -0.360208
#
# ...

# %%
balanced_data.to_csv('balanced_rf_data.csv', index=False)
