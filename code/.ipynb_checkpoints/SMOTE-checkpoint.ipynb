# %%
# Loading Libraries
from imblearn.over_sampling import SMOTE
from sklearn.datasets import make_classification
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
import pandas as pd

# %%
# Loading Data
data = pd.read_csv('C:\\Users\\student\\Documents\\DSE 6311\\Module 5\\pca_data.csv')
data = data.drop('Tm', axis=1)
data
# Out:
#           PC1        PC2       PC3       PC4       PC5       PC6       PC7  \
# 0   -4.282790  13.592870 -1.724308 -0.432617 -3.902741 -5.450866  2.462349
# 1   -1.869663   4.204504  4.406656  6.953573 -2.440491 -1.851361  2.333124
# 2   -6.998419   3.376499  5.466140  2.477125 -2.753743 -1.547390  0.540792
# 3    1.459629  11.089163 -0.065439  0.050025 -2.930221  2.027066  4.460698
# 4   -2.904890   3.216293  4.691585  7.019772 -0.824494 -1.173097  2.876965
# ..        ...        ...       ...       ...       ...       ...       ...
# 715  1.345193  -6.549318 -1.774004  0.035891  0.704378  0.109788  0.287484
# 716  4.658020 -11.330853 -3.039703  2.002259 -2.164231 -1.150981  3.610617
# 717  3.203020  -7.412263 -6.491278 -1.546576 -1.781930 -0.649332  1.109149
# 718  2.135326  -5.826363 -6.860579 -3.775389 -3.503148 -2.040305  0.329693
# 719  7.131424  -5.306325 -3.002520 -1.806283 -0.245107  1.195322  1.182909
#
#           PC8       PC9      PC10  ...      PC14      PC15      PC16  \
# 0    0.811741 -2.436246 -2.342775  ... -2.871497 -0.695479 -1.146376
# 1    0.386007  2.360705 -0.387307  ...  0.173869  1.744253  1.627004
# 2    0.856969  2.444523  0.943575  ... -1.589606 -0.988637 -1.022371
# 3    1.479107  2.845746 -1.662170  ... -3.307837  1.089369  2.429690
# 4    1.482737 -0.324031 -3.110583  ...  0.616903  2.079816 -4.039467
# ..        ...       ...       ...  ...       ...       ...       ...
# 715 -1.346461  1.465618 -1.830450  ...  0.191194  0.326889 -1.476743
# 716 -1.412337 -0.780273  2.427751  ...  1.218038 -1.334805 -1.607271
# 717  0.965376  5.821690 -0.557210  ... -1.252168  0.716593 -1.025330
# 718  0.852449  5.490312 -2.082755  ...  0.594460  2.088639 -1.170426
# 719 -3.320664 -0.013578  1.920417  ... -1.301437 -2.364840 -0.020392
#
#          PC17      PC18      PC19      PC20  Cluster  TeamSuccess  Year
# 0   -0.136067  0.075654 -1.834792  2.129972        3            1  2000
# 1    1.184269 -2.010392  0.758406  1.028807        3            1  2000
# 2   -1.869875 -0.401252 -0.306656 -0.043046        3            2  2000
# 3   -1.630864  1.721382 -1.256351  0.263239        3            1  2000
# 4    0.865857 -1.838806  0.343712  2.088303        3            1  2000
# ..        ...       ...       ...       ...      ...          ...   ...
# 715  1.886318  1.284236  1.663219  1.824706        2            1  2024
# 716  1.360572  0.712302 -0.429575  0.118972        2            1  2024
# 717  1.435209 -0.855854  1.345620  0.388656        2            1  2024
# 718  1.033682 -0.635772 -1.183931  1.692003        2            1  2024
# 719 -0.658953  2.009501 -0.793904  1.813894        1            1  2024
#
# [720 rows x 23 columns]

# %%
# Splitting Data
X = data.drop('TeamSuccess', axis=1) 
y = data['TeamSuccess']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.22, random_state=123)

# Prinitng Before SMOTE Data
print("Before SMOTE:", Counter(y_train))

# Running SMOTE
smote = SMOTE(random_state=123)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Printing After SMOTE Data
print("After SMOTE:", Counter(y_train_res))
# Out:
# Before SMOTE: Counter({1: 389, 2: 137, 4: 18, 3: 17})
# After SMOTE: Counter({2: 389, 1: 389, 4: 389, 3: 389})

# %%
# Creating New Resampled Data
X_resampled_data = pd.DataFrame(X_train_resampled, columns=X.columns)
y_resampled_data = pd.Series(y_train_resampled, name='TeamSuccess')

# Combining Resampled Data
balanced_data = pd.concat([X_resampled_data, y_resampled_data], axis=1)
balanced_data
# Out:
#             PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0     -5.580423  3.447394  3.054254 -0.320681  0.120097  1.944348  1.305813
# 1     13.439613  8.631301  0.015155 -0.510663  1.516149  5.195185  0.956815
# 2     -1.465315 -6.962353  0.856471  1.593950  2.784434  2.259712 -3.499540
# 3      0.246742  8.590330  5.632433  2.941791  1.349642 -4.029075 -2.307981
# 4    -11.459877 -7.926757 -2.829819  3.039212  0.623141  0.378751  0.272115
# ...         ...       ...       ...       ...       ...       ...       ...
# 1551  -8.508130  1.792369  4.068767  2.736306 -0.997633  0.951186  0.336119
# 1552 -12.605617 -2.779903 -8.696407 -3.483926 -1.254175 -0.134029  0.072678
# 1553 -13.100763 -0.177088 -3.251521 -1.198297  1.335568  0.945755 -1.839415
# 1554  -2.920874  5.942567  1.610094  0.653303 -7.047894  1.534162 -5.041239
# 1555  -5.487544 -1.033564  3.818349 -7.123615  1.626375  3.065472 -2.621017
#
#            PC8       PC9      PC10  ...      PC14      PC15      PC16  \
# 0    -3.241866  1.108404  0.657862  ... -0.783436 -3.346499  0.679180
# 1    -2.964237 -0.960557  1.634937  ... -1.145812  0.218581 -0.714480
# 2    -1.104488  0.069788 -1.152906  ...  1.660459  1.513823  0.575965
# 3    -0.023173 -1.146717  0.973585  ...  1.282982  1.018547 -1.569782
# 4     2.936137 -1.632364  1.256718  ...  0.962123 -0.003734 -1.293410
# ...        ...       ...       ...  ...       ...       ...       ...
# 1551 -2.132944  0.643523  2.281655  ...  0.841187  0.340595 -0.067981
# 1552  0.521884  1.654571  1.666055  ... -1.645605  0.326122  0.044936
# 1553 -2.198121  0.499378  0.714324  ... -0.303050  1.503170  0.918430
# 1554  1.876298  1.388580 -2.433129  ...  0.345978 -1.077893 -0.766646
# 1555  0.382224  0.195162  0.697538  ... -0.691045 -1.457037 -0.190220
#
#           PC17      PC18      PC19      PC20  Cluster  Year  TeamSuccess
# 0     0.466563 -0.298435  2.021436  0.851582        3  2004            2
# 1     0.255197 -0.381517 -0.091337 -0.152282        1  2005            1
# 2    -0.569866  1.020278 -0.061556  0.644287        2  2015            1
# 3     0.211065 -1.242673  0.801984 -1.286635        3  2006            1
# 4     0.272276  0.201319  0.271558 -1.650929        2  2021            2
# ...        ...       ...       ...       ...      ...   ...          ...
# 1551 -0.959220  0.947973  0.679810 -0.188703        3  2005            4
# 1552  0.493031  0.191682 -0.569753 -0.257010        2  2022            4
# 1553 -0.287059  0.716146  0.211652  0.135883        2  2015            4
# 1554 -0.162590 -0.495869  0.549586 -1.042432        3  2004            4
# 1555  0.489412 -0.960782 -1.339320 -1.786948        2  2011            4
#
# [1556 rows x 23 columns]

# %%
# balanced_data.to_csv('balanced_data.csv', index=False)
